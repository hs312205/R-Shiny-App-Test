# %%
import pandas as pd

df_data_1 = pd.read_csv('/project_data/data_asset/customer.csv')
df_data_1.head()
# Out:
#    ACQUISITION_COST ADDRESS_HOME_CITY ADDRESS_HOME_COUNTRY  \
# 0         55.026993      Emerald City                  USA
# 1         19.712715         Coruscant                  USA
# 2         81.473346        Metropolis               Canada
# 3         58.943523      Emerald City                  USA
# 4         74.091664        Smallville                  USA
#
#   ADDRESS_HOME_POSTAL_CODE ADDRESS_HOME_STATE ADDRESS_LAST_CHANGED_DATE  \
# 0                      B1Z            Indiana                2015-06-06
# 1                      K0K                New                2015-03-27
# 2                      G1K                 QC                2015-01-31
# 3                      P0J           Nebraska                2017-10-08
# 4                      G1P           Colorado                2016-10-26
#
#   ADDRESS_MAILING_CITY ADDRESS_MAILING_COUNTRY ADDRESS_MAILING_POSTAL_CODE  \
# 0         Emerald City                     USA                         B1Z
# ...
